# %%
import pandas as pd
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize
import re
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Khashayar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df = pd.read_csv('fake_job_postings.csv')
df.head(10)
# Out:
#    job_id                                      title               location  \
# 0       1                           Marketing Intern       US, NY, New York
# 1       2  Customer Service - Cloud Video Production         NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)          US, IA, Wever
# 3       4          Account Executive - Washington DC     US, DC, Washington
# 4       5                        Bill Review Manager     US, FL, Fort Worth
# 5       6                           Accounting Clerk               US, MD,
# 6       7                      Head of Content (m/f)         DE, BE, Berlin
# 7       8           Lead Guest Service Specialist     US, CA, San Francisco
# 8       9                                 HP BSM SME      US, FL, Pensacola
# 9      10    Customer Service Associate - Part Time         US, AZ, Phoenix
#
#    department salary_range                                    company_profile  \
# ...

# %%
example_string = df['description'][4]
sent_tokenize(example_string)
# Out:
# ['JOB TITLE: Itemization Review ManagerLOCATION: Fort Worth, TX\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 DEPARTMENT: Itemization ReviewREPORTS TO: VP Operations\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0GENERAL DESCRIPTION:Responsible for the overall aspects of Itemization Review operations: Personnel Hiring, Quality Control of Process, Workflow, monitoring the tracking of and accountability of staff regarding production standards and department expectations.DUTIES AND RESPONSIBILITIES:Oversee company’s Itemization Review department in its operationsResponsible for encouraging and reinforcing company cultureDevelops processes to better department and implements new procedures/protocols Works with Customer Service on elevated issues and provider callsImplements and Audits p
# ...

# %%
word_tokenize(example_string)
# Out:
# ['JOB',
#  'TITLE',
#  ':',
#  'Itemization',
#  'Review',
#  'ManagerLOCATION',
#  ':',
#  'Fort',
#  'Worth',
#  ',',
#  'TX',
#  'DEPARTMENT',
#  ':',
#  'Itemization',
#  'ReviewREPORTS',
#  'TO',
#  ':',
#  'VP',
#  'Operations',
#  'GENERAL',
#  'DESCRIPTION',
#  ':',
#  'Responsible',
#  'for',
#  'the',
#  'overall',
#  'aspects',
#  'of',
#  'Itemization',
#  'Review',
#  'operations',
#  ':',
#  'Personnel',
#  'Hiring',
#  ',',
#  'Quality',
#  'Control',
#  'of',
#  'Process',
#  ',',
#  'Workflow',
#  ',',
#  'monitoring',
#  'the',
#  'tracking',
#  'of',
#  'and',
#  'accountability',
#  'of',
#  'staff',
#  'regarding',
#  'production',
#  'standards',
#  'and',
#  'department',
#  'expectations.DUTIES',
#  'AND',
#  'RESPONSIBILITIES',
#  ':',
#  'Oversee',
#  'company',
#  '’',
#  's',
#  'Itemization',
#  'Review',
#  'department',
#  'in',
#  'its',
#  'operationsResponsible',
#  'for',
#  'encouraging',
#  'and',
#  'reinforcing',
#  'company',
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
# Out:
# ['JOB',
#  'TITLE',
#  ':',
#  'Itemization',
#  'Review',
#  'ManagerLOCATION',
#  ':',
#  'Fort',
#  'Worth',
#  ',',
#  'TX',
#  'DEPARTMENT',
#  ':',
#  'Itemization',
#  'ReviewREPORTS',
#  'TO',
#  ':',
#  'VP',
#  'Operations',
#  'GENERAL',
#  'DESCRIPTION',
#  ':',
#  'Responsible',
#  'for',
#  'the',
#  'overall',
#  'aspects',
#  'of',
#  'Itemization',
#  'Review',
#  'operations',
#  ':',
#  'Personnel',
#  'Hiring',
#  ',',
#  'Quality',
#  'Control',
#  'of',
#  'Process',
#  ',',
#  'Workflow',
#  ',',
#  'monitoring',
#  'the',
#  'tracking',
#  'of',
#  'and',
#  'accountability',
#  'of',
#  'staff',
#  'regarding',
#  'production',
#  'standards',
#  'and',
#  'department',
#  'expectations.DUTIES',
#  'AND',
#  'RESPONSIBILITIES',
#  ':',
#  'Oversee',
#  'company',
#  '’',
#  's',
#  'Itemization',
#  'Review',
#  'department',
#  'in',
#  'its',
#  'operationsResponsible',
#  'for',
#  'encouraging',
#  'and',
#  'reinforcing',
#  'company',
# ...

# %%
import nltk
from nltk import word_tokenize
text = word_tokenize(example_string)
output = nltk.pos_tag(text)
print(output)
# Out:
# [('JOB', 'NNP'), ('TITLE', 'NNP'), (':', ':'), ('Itemization', 'NNP'), ('Review', 'NNP'), ('ManagerLOCATION', 'NNP'), (':', ':'), ('Fort', 'NNP'), ('Worth', 'NNP'), (',', ','), ('TX', 'NNP'), ('DEPARTMENT', 'NNP'), (':', ':'), ('Itemization', 'NN'), ('ReviewREPORTS', 'NNP'), ('TO', 'NNP'), (':', ':'), ('VP', 'NNP'), ('Operations', 'NNP'), ('GENERAL', 'NNP'), ('DESCRIPTION', 'NNP'), (':', ':'), ('Responsible', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('overall', 'JJ'), ('aspects', 'NNS'), ('of', 'IN'), ('Itemization', 'NNP'), ('Review', 'NNP'), ('operations', 'NNS'), (':', ':'), ('Personnel', 'NNS'), ('Hiring', 'VBG'), (',', ','), ('Quality', 'NNP'), ('Control', 'NNP'), ('of', 'IN'), ('Process', 'NNP'), (',', ','), ('Workflow', 'NNP'), (',', ','), ('monitoring', 'VBG'), ('the', 'DT'), ('tracking', 'NN'), ('of', 'IN'), ('and', 'CC'), ('accountability', 'NN'), ('of', 'IN'), ('staff', 'NN'), ('regarding', 'VBG'), ('production', 'NN'), ('standards', 'NNS'), ('and', 'CC'), ('department', 'NN')
# ...

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(example_string)
# Out:
# ['JOB',
#  'TITLE',
#  ':',
#  'Itemization',
#  'Review',
#  'ManagerLOCATION',
#  ':',
#  'Fort',
#  'Worth',
#  ',',
#  'TX',
#  'DEPARTMENT',
#  ':',
#  'Itemization',
#  'ReviewREPORTS',
#  'TO',
#  ':',
#  'VP',
#  'Operations',
#  'GENERAL',
#  'DESCRIPTION',
#  ':',
#  'Responsible',
#  'for',
#  'the',
#  'overall',
#  'aspects',
#  'of',
#  'Itemization',
#  'Review',
#  'operations',
#  ':',
#  'Personnel',
#  'Hiring',
#  ',',
#  'Quality',
#  'Control',
#  'of',
#  'Process',
#  ',',
#  'Workflow',
#  ',',
#  'monitoring',
#  'the',
#  'tracking',
#  'of',
#  'and',
#  'accountability',
#  'of',
#  'staff',
#  'regarding',
#  'production',
#  'standards',
#  'and',
#  'department',
#  'expectations',
#  '.',
#  'DUTIES',
#  'AND',
#  'RESPONSIBILITIES',
#  ':',
#  'Oversee',
#  'company',
#  '’',
#  's',
#  'Itemization',
#  'Review',
#  'department',
#  'in',
#  'its',
#  'operationsResponsible',
#  'for',
#  'encouraging',
#  'and',
#  'reinforcing',
#  'company',
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
sent_tokenize(example_string)
# Out:
# ['JOB TITLE: Itemization Review ManagerLOCATION: Fort Worth, TX\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 DEPARTMENT: Itemization ReviewREPORTS TO: VP Operations\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0GENERAL DESCRIPTION:Responsible for the overall aspects of Itemization Review operations: Personnel Hiring, Quality Control of Process, Workflow, monitoring the tracking of and accountability of staff regarding production standards and department expectations.DUTIES AND RESPONSIBILITIES:Oversee company’s Itemization Review department in its operationsResponsible for encouraging and reinforcing company cultureDevelops processes to better department and implements new procedures/protocols Works with Customer Service on elevated issues and provider callsImplements and Audits p
# ...

# %%
[word_tokenize(t) for t in sent_tokenize(example_string)]
# Out:
# [['JOB',
#   'TITLE',
#   ':',
#   'Itemization',
#   'Review',
#   'ManagerLOCATION',
#   ':',
#   'Fort',
#   'Worth',
#   ',',
#   'TX',
#   'DEPARTMENT',
#   ':',
#   'Itemization',
#   'ReviewREPORTS',
#   'TO',
#   ':',
#   'VP',
#   'Operations',
#   'GENERAL',
#   'DESCRIPTION',
#   ':',
#   'Responsible',
#   'for',
#   'the',
#   'overall',
#   'aspects',
#   'of',
#   'Itemization',
#   'Review',
#   'operations',
#   ':',
#   'Personnel',
#   'Hiring',
#   ',',
#   'Quality',
#   'Control',
#   'of',
#   'Process',
#   ',',
#   'Workflow',
#   ',',
#   'monitoring',
#   'the',
#   'tracking',
#   'of',
#   'and',
#   'accountability',
#   'of',
#   'staff',
#   'regarding',
#   'production',
#   'standards',
#   'and',
#   'department',
#   'expectations.DUTIES',
#   'AND',
#   'RESPONSIBILITIES',
#   ':',
#   'Oversee',
#   'company',
#   '’',
#   's',
#   'Itemization',
#   'Review',
#   'department',
#   'in',
#   'its',
#   'operationsResponsible',
#   'for',
# ...

# %%
from nltk.tokenize import WhitespaceTokenizer
list(WhitespaceTokenizer().span_tokenize(example_string))
# Out:
# [(0, 3),
#  (4, 10),
#  (11, 22),
#  (23, 29),
#  (30, 46),
#  (47, 51),
#  (52, 58),
#  (59, 61),
#  (120, 131),
#  (132, 143),
#  (144, 157),
#  (158, 161),
#  (162, 164),
#  (165, 175),
#  (203, 210),
#  (211, 234),
#  (235, 238),
#  (239, 242),
#  (243, 250),
#  (251, 258),
#  (259, 261),
#  (262, 273),
#  (274, 280),
#  (281, 292),
#  (293, 302),
#  (303, 310),
#  (311, 318),
#  (319, 326),
#  (327, 329),
#  (330, 338),
#  (339, 348),
#  (349, 359),
#  (360, 363),
#  (364, 372),
#  (373, 375),
#  (376, 379),
#  (380, 394),
#  (395, 397),
#  (398, 403),
#  (404, 413),
#  (414, 424),
#  (425, 434),
#  (435, 438),
#  (439, 449),
#  (450, 469),
#  (470, 473),
#  (474, 498),
#  (499, 508),
#  (509, 520),
#  (521, 527),
#  (528, 538),
#  (539, 541),
#  (542, 545),
#  (546, 567),
#  (568, 571),
#  (572, 583),
#  (584, 587),
#  (588, 599),
#  (600, 607),
#  (608, 623),
#  (624, 633),
#  (634, 636),
#  (637, 643),
#  (644, 654),
#  (655, 658),
#  (659, 669),
#  (670, 673),
# ...
